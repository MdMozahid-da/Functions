# %% [markdown]
# #Functions

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#  - Function: A block of code that performs a specific task and can be
#     called independently. Defined using the def keyword.
#
#     Method: A function that is associated with an object and is called on that object. Methods are defined within a class and have access to the object's data.

# %%
'''
def function_example():
    return "I am a function."
'''

"""
class MyClass:
    def method_example(self):
        return "I am a method."
"""

# %% [markdown]
# 2. Explain the concept of function arguments and parameters in Python.
#  - Parameters: Variables listed inside the parentheses in the function
#   definition.
#
#     Arguments: Values passed to the function when it is called.

# %%
'''
def greet(name):  # 'name' is a parameter
    return f"Hello, {name}!"

greet("Alice")  # "Alice" is an argument
'''

# %% [markdown]
# 3. What are the different ways to define and call a function in Python?

# %%
#Defining a function
'''
def greet(name):
    return f"Hello, {name}!"
'''
#Calling a function
"""
greet("Alice")
"""

# %% [markdown]
# 4. What is the purpose of the return statement in a Python function?
#  - The return statement ends the function execution and optionally
#    passes back a value to the caller.

# %%
'''
def add(a, b):
    return a + b
'''

# %% [markdown]
# 5. What are iterators in Python and how do they differ from iterables?
#  - Iterables: Objects that can be iterated over (e.g., lists, tuples).
#
#     Iterators: Objects that can be used to iterate through an iterable, using the __next__() method.

# %%
'''
my_list = [1, 2, 3]
my_iterator = iter(my_list)

print(next(my_iterator))  # Output: 1
'''

# %% [markdown]
# 6. Explain the concept of generators in Python and how they are defined.
#  - Generators are functions that return an iterator that yields values
#    one at a time, using the "yield" keyword.

# %%
'''
def count_up_to(max):
    count = 1
    while count <= max:
        yield count
        count += 1

counter = count_up_to(5)
for number in counter:
    print(number)
'''

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?
#  - -> Generators are memory efficient.
#
#     ->They allow for lazy evaluation.
#
#     ->Useful for handling large data sets or infinite sequences.

# %% [markdown]
# 8. What is a lambda function in Python and when is it typically used?
#  - A lambda function is a small anonymous function defined with the lambda keyword. It's used for creating small, throwaway functions without a name.

# %%
'''
add = lambda x, y: x + y
print(add(3, 5))  # Output: 8
'''

# %% [markdown]
# 9. Explain the purpose and usage of the "map()" function in Python.
#  - The "map()" function applies a given function to all items in an iterable and returns a map object.

# %%
'''
numbers = [1, 2, 3, 4]
squared = map(lambda x: x ** 2, numbers)
print(list(squared))  # Output: [1, 4, 9, 16]
'''

# %% [markdown]
# 10. What is the difference between map(), reduce(), and filter() functions in Python?
#  - map(): Applies a function to all items in an iterable.
#
#     reduce(): Reduces an iterable to a single value by applying a function cumulatively.
#
#     filter(): Filters elements in an iterable based on a function that returns True or False.

# %%
'''
from functools import reduce

numbers = [1, 2, 3, 4]

# Using map()
squared = list(map(lambda x: x ** 2, numbers))

# Using reduce()
sum_numbers = reduce(lambda x, y: x + y, numbers)

# Using filter()
even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
'''

# %% [markdown]
# 11. Using pen & paper write the internal mechanism for sum operation using reduce function on this given list: [47, 11, 42, 13];
# ![20250121_230414.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Practical questions

# %% [markdown]
# 1.  Write a Python function that takes a list of numbers as input and
#   returns the sum of all even numbers in the list.

# %%
#Sum of all even numbers in a list
'''
def sum_of_evens(numbers):
    return sum(num for num in numbers if num % 2 == 0)
'''

# %% [markdown]
# 2. Create a Python function that accepts a string and returns the reverse of that string.

# %%
#Reverse a string
'''
def reverse_string(s):
    return s[::-1]
'''

# %% [markdown]
# 3.  Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

# %%
#Squares of each number in a list
'''
def square_numbers(numbers):
    return [num ** 2 for num in numbers]
'''

# %% [markdown]
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
'''
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True
'''

# %% [markdown]
# 5.  Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

# %%
'''
class FibonacciIterator:
    def __init__(self, n_terms):
        self.n_terms = n_terms
        self.current = 0
        self.next = 1
        self.count = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count < self.n_terms:
            fib = self.current
            self.current, self.next = self.next, self.current + self.next
            self.count += 1
            return fib
        else:
            raise StopIteration
'''

# %% [markdown]
# 6.  Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
'''
def powers_of_2(exponent):
    for i in range(exponent + 1):
        yield 2 ** i
'''

# %% [markdown]
# 7. Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
'''
def read_lines(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            yield line.strip()
'''

# %% [markdown]
# 8.  Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
'''
sort_tuples = lambda tuples: sorted(tuples, key=lambda x: x[1])
'''

# %% [markdown]
# 9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# %%
'''
def celsius_to_fahrenheit(celsius_list):
    return list(map(lambda c: (c * 9/5) + 32, celsius_list))
'''

# %% [markdown]
# 10.  Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %%
'''
def remove_vowels(input_string):
    vowels = "aeiouAEIOU"
    return "".join(filter(lambda char: char not in vowels, input_string))

#Example usage
input_string = "Hello, World!"
output_string = remove_vowels(input_string)
print(output_string)

'''

# %% [markdown]
# 12. Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this

# %%
'''
orders = [
    (34587, "Learning Python, Mark Lutz", 4, 40.95),
    (98762, "Programming Python, Mark Lutz", 5, 56.80),
    (77226, "Head First Python, Paul Barry", 3, 32.95),
    (88112, "Einführung in Python3, Bernd Klein", 3, 24.99)
]

result = list(map(lambda order: (order[0], order[2] * order[3] if order[2] * order[3] >= 100 else order[2] * order[3] + 10), orders))
print(result)
'''

# %% [markdown]
# - -> Defines a list of tuples, each containing the order number, book
#     title and author, quantity, and price per item.
#
# ->  Uses the map function with a lambda function to process each order.
#     The lambda function calculates the total price (quantity * price per item) and checks if it is smaller than 100. If it is, it adds 10 to the total price. It returns a tuple with the order number and the final calculated price.
#
# ->  Converts the result to a list and prints it.
